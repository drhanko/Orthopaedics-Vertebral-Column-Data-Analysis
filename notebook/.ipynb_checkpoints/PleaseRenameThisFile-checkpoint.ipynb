# %% [markdown]
# DSCI 552 Homework X
# ===================
#
# - Name: [Your Name Here]
# - GitHub Username: [Your GitHub Username Here]
# - USD ID: 1234-5678-90

# %%
print("hello world")
# Out:
# hello world
